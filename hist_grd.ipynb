# %% [markdown]
# HistGradientBoostingClassifier

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import optuna
import numpy as np
import pandas as pd

# %%
#Importation des données clean
X_train=pd.read_csv("data/X_train_after_selection.csv")
y_train=pd.read_csv("data/y_train.csv")
X_val=pd.read_csv("data/X_val_after_selection.csv")
y_val=pd.read_csv("data/y_val.csv")
X_test=pd.read_csv("data/X_test.csv")

data_test = pd.read_csv("data/test.csv")

# %%
X_full, y_full  = pd.concat([X_train,X_val],axis=0,ignore_index=True), pd.concat([y_train,y_val],axis=0,ignore_index=True)

# %%
X_full
# Out:
#        CreditScore   Age  Tenure    Balance  NumOfProducts  IsActiveMember  \
# 0            646.0  38.0     4.0       0.00            2.0               0
# 1            595.0  30.0     4.0  146329.57            1.0               0
# 2            648.0  31.0     7.0   98592.88            1.0               1
# 3            687.0  35.0     4.0       0.00            2.0               1
# 4            676.0  26.0    10.0       0.00            2.0               0
# ...            ...   ...     ...        ...            ...             ...
# 14994        696.0  44.0     1.0       0.00            2.0               1
# 14995        523.0  33.0     7.0       0.00            2.0               1
# 14996        607.0  31.0     4.0       0.00            2.0               0
# 14997        667.0  36.0     1.0       0.00            2.0               1
# 14998        693.0  39.0     6.0  121527.40            2.0               1
#
#        EstimatedSalary  Geography_Germany  Gender_Male
# 0               479.56                  0            1
# 1             79329.70                  0            0
# 2            187925.75                  0            1
# 3             83470.40                  0            0
# 4             83342.73                  0            1
# ...                ...                ...          ...
# 14994        121789.30                  0            0
# 14995         92320.36                  0            1
# 14996         60917.24                  0            0
# 14997        102299.81                  0            1
# 14998        115525.13                  1            0
#
# [14999 rows x 9 columns]

# %%
categorical_features = ['IsActiveMember', 'Geography_Germany', 'Gender_Male']

for col in categorical_features:
    X_full[col] = X_full[col].astype('int')
    X_test[col] = X_test[col].astype('int')

# %%
def objective(trial):
    params = {
        'learning_rate': trial.suggest_float('learning_rate', 0.0001, 0.3),
        'max_iter': trial.suggest_int('max_iter', 50, 500),
        'max_leaf_nodes': trial.suggest_int('max_leaf_nodes', 10, 50),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 5, 50),
        'l2_regularization': trial.suggest_float('l2_regularization', 0.0, 1.0),
        'early_stopping': True,
        'validation_fraction': 0.1,
        'random_state': trial.suggest_int('random_state',0, 10000)
    }
    
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    auc_scores = []
    
    for train_idx, val_idx in skf.split(X_train, y_train):
        X_train_fold, X_val_fold = X_train.iloc[train_idx], X_train.iloc[val_idx].ravel()
        y_train_fold, y_val_fold = y_train.iloc[train_idx], y_train.iloc[val_idx].ravel()
        
        model = HistGradientBoostingClassifier(**params)
        model.fit(X_train_fold, y_train_fold)
        
        y_val_pred = model.predict_proba(X_val_fold)[:, 1]
        auc = roc_auc_score(y_val_fold, y_val_pred)
        auc_scores.append(auc)
    
    return np.mean(auc_scores)

# Create a study and optimize
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=750)

# Best hyperparameters
print("Best parameters:", study.best_params)
print("Best AUC score:", study.best_value)
# Out:
# [I 2024-12-31 17:33:07,937] A new study created in memory with name: no-name-58935a83-d47b-42d0-84aa-9d89f5bcb92d
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:09,094] Trial 0 finished with value: 0.9363789879416778 and parameters: {'learning_rate': 0.02247182840542502, 'max_iter': 156, 'max_leaf_nodes': 11, 'max_depth': 14, 'min_samples_leaf': 7, 'l2_regularization': 0.18452423035396648, 'random_state': 4358}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:09,955] Trial 1 finished with value: 0.9310887706151785 and parameters: {'learning_rate': 0.16229273869845404, 'max_iter': 491, 'max_leaf_nodes': 47, 'max_depth': 10, 'min_samples_leaf': 22, 'l2_regularization': 0.6382126866188156, 'random_state': 3164}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:10,554] Trial 2 finished with value: 0.9277157886383319 and parameters: {'learning_rate': 0.25831747162696755, 'max_iter': 456, 'max_leaf_nodes': 45, 'max_depth': 12, 'min_samples_leaf': 22, 'l2_regularization': 0.37111712861701085, 'random_state': 6990}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:11,824] Trial 3 finished with value: 0.9327553774000272 and parameters: {'learning_rate': 0.07216533330230754, 'max_iter': 145, 'max_leaf_nodes': 41, 'max_depth': 11, 'min_samples_leaf': 12, 'l2_regularization': 0.09646075768398532, 'random_state': 6434}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:15,284] Trial 4 finished with value: 0.9359486415861464 and parameters: {'learning_rate': 0.009862719858327268, 'max_iter': 350, 'max_leaf_nodes': 26, 'max_depth': 5, 'min_samples_leaf': 37, 'l2_regularization': 0.9251773092377427, 'random_state': 2006}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:15,922] Trial 5 finished with value: 0.9326515196135092 and parameters: {'learning_rate': 0.1570738770467575, 'max_iter': 65, 'max_leaf_nodes': 28, 'max_depth': 15, 'min_samples_leaf': 12, 'l2_regularization': 0.3038546767435367, 'random_state': 6681}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:17,108] Trial 6 finished with value: 0.9319207224749878 and parameters: {'learning_rate': 0.08098019616545361, 'max_iter': 107, 'max_leaf_nodes': 41, 'max_depth': 14, 'min_samples_leaf': 21, 'l2_regularization': 0.005256022494066093, 'random_state': 3439}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:17,540] Trial 7 finished with value: 0.9308994029591864 and parameters: {'learning_rate': 0.23696110678001858, 'max_iter': 100, 'max_leaf_nodes': 26, 'max_depth': 10, 'min_samples_leaf': 43, 'l2_regularization': 0.4670263189717909, 'random_state': 5765}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:18,073] Trial 8 finished with value: 0.9329957221448787 and parameters: {'learning_rate': 0.1913185611541151, 'max_iter': 424, 'max_leaf_nodes': 24, 'max_depth': 10, 'min_samples_leaf': 48, 'l2_regularization': 0.26895310111110926, 'random_state': 7450}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:18,585] Trial 9 finished with value: 0.9330919827109294 and parameters: {'learning_rate': 0.200998441904561, 'max_iter': 96, 'max_leaf_nodes': 23, 'max_depth': 8, 'min_samples_leaf': 23, 'l2_regularization': 0.4566104315200644, 'random_state': 9930}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:20,037] Trial 10 finished with value: 0.9253961395974242 and parameters: {'learning_rate': 0.00682087697646605, 'max_iter': 231, 'max_leaf_nodes': 10, 'max_depth': 3, 'min_samples_leaf': 6, 'l2_regularization': 0.6839920915379638, 'random_state': 269}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:22,435] Trial 11 finished with value: 0.9354251853177956 and parameters: {'learning_rate': 0.009366365059720086, 'max_iter': 336, 'max_leaf_nodes': 11, 'max_depth': 6, 'min_samples_leaf': 35, 'l2_regularization': 0.9167145359594953, 'random_state': 1430}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:23,371] Trial 12 finished with value: 0.936313377482243 and parameters: {'learning_rate': 0.06478012146676213, 'max_iter': 270, 'max_leaf_nodes': 17, 'max_depth': 5, 'min_samples_leaf': 35, 'l2_regularization': 0.9601929963044008, 'random_state': 3689}. Best is trial 0 with value: 0.9363789879416778.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:24,188] Trial 13 finished with value: 0.9364006675808205 and parameters: {'learning_rate': 0.08302348294444686, 'max_iter': 220, 'max_leaf_nodes': 16, 'max_depth': 7, 'min_samples_leaf': 33, 'l2_regularization': 0.7296371106481604, 'random_state': 4317}. Best is trial 13 with value: 0.9364006675808205.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:24,986] Trial 14 finished with value: 0.9360508265886068 and parameters: {'learning_rate': 0.10409391887842484, 'max_iter': 197, 'max_leaf_nodes': 17, 'max_depth': 8, 'min_samples_leaf': 29, 'l2_regularization': 0.6973542357171649, 'random_state': 4617}. Best is trial 13 with value: 0.9364006675808205.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:26,756] Trial 15 finished with value: 0.9332316005714363 and parameters: {'learning_rate': 0.045899101776443636, 'max_iter': 164, 'max_leaf_nodes': 34, 'max_depth': 13, 'min_samples_leaf': 28, 'l2_regularization': 0.7962956335872948, 'random_state': 4860}. Best is trial 13 with value: 0.9364006675808205.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:27,442] Trial 16 finished with value: 0.9356324196898035 and parameters: {'learning_rate': 0.12067105851819987, 'max_iter': 253, 'max_leaf_nodes': 17, 'max_depth': 7, 'min_samples_leaf': 14, 'l2_regularization': 0.19417333540832893, 'random_state': 8656}. Best is trial 13 with value: 0.9364006675808205.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:28,803] Trial 17 finished with value: 0.9377318115501325 and parameters: {'learning_rate': 0.04129713399344191, 'max_iter': 345, 'max_leaf_nodes': 14, 'max_depth': 3, 'min_samples_leaf': 6, 'l2_regularization': 0.588847254334308, 'random_state': 2152}. Best is trial 17 with value: 0.9377318115501325.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:29,423] Trial 18 finished with value: 0.9380270676440734 and parameters: {'learning_rate': 0.11389350741749148, 'max_iter': 328, 'max_leaf_nodes': 34, 'max_depth': 3, 'min_samples_leaf': 41, 'l2_regularization': 0.5724371963500671, 'random_state': 2065}. Best is trial 18 with value: 0.9380270676440734.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:29,783] Trial 19 finished with value: 0.9366360678202609 and parameters: {'learning_rate': 0.29371734507509517, 'max_iter': 330, 'max_leaf_nodes': 33, 'max_depth': 3, 'min_samples_leaf': 42, 'l2_regularization': 0.5665080870007205, 'random_state': 2100}. Best is trial 18 with value: 0.9380270676440734.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:30,371] Trial 20 finished with value: 0.9366668155707065 and parameters: {'learning_rate': 0.12471947141763726, 'max_iter': 381, 'max_leaf_nodes': 35, 'max_depth': 4, 'min_samples_leaf': 48, 'l2_regularization': 0.5373071348805795, 'random_state': 460}. Best is trial 18 with value: 0.9380270676440734.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:30,996] Trial 21 finished with value: 0.9366123073255134 and parameters: {'learning_rate': 0.12400397950780048, 'max_iter': 379, 'max_leaf_nodes': 37, 'max_depth': 4, 'min_samples_leaf': 48, 'l2_regularization': 0.5077155274131344, 'random_state': 123}. Best is trial 18 with value: 0.9380270676440734.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:31,571] Trial 22 finished with value: 0.936947941921016 and parameters: {'learning_rate': 0.12991571271605198, 'max_iter': 302, 'max_leaf_nodes': 32, 'max_depth': 4, 'min_samples_leaf': 42, 'l2_regularization': 0.5788926291039893, 'random_state': 1150}. Best is trial 18 with value: 0.9380270676440734.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:32,045] Trial 23 finished with value: 0.9377256161624755 and parameters: {'learning_rate': 0.18563137500252508, 'max_iter': 311, 'max_leaf_nodes': 31, 'max_depth': 3, 'min_samples_leaf': 42, 'l2_regularization': 0.6021181940923742, 'random_state': 1465}. Best is trial 18 with value: 0.9380270676440734.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:32,468] Trial 24 finished with value: 0.9369147556220658 and parameters: {'learning_rate': 0.1796898898491261, 'max_iter': 301, 'max_leaf_nodes': 39, 'max_depth': 3, 'min_samples_leaf': 40, 'l2_regularization': 0.8278547986234075, 'random_state': 2627}. Best is trial 18 with value: 0.9380270676440734.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:33:33,934] Trial 25 finished with value: 0.9363387146923273 and parameters: {'learning_rate': 0.03984344644594099, 'max_iter': 417, 'max_leaf_nodes': 21, 'max_depth': 5, 'min_samples_leaf': 31, 'l2_regularization': 0.41192234630128455, 'random_state': 1331}. Best is trial 18 with value: 0.9380270676440734.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:44:41,342] Trial 741 finished with value: 0.9376176709775799 and parameters: {'learning_rate': 0.09228852734696424, 'max_iter': 347, 'max_leaf_nodes': 34, 'max_depth': 3, 'min_samples_leaf': 26, 'l2_regularization': 0.8888089273875517, 'random_state': 1067}. Best is trial 164 with value: 0.9386104925733989.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:44:42,258] Trial 742 finished with value: 0.936806478208935 and parameters: {'learning_rate': 0.04238553219309244, 'max_iter': 120, 'max_leaf_nodes': 44, 'max_depth': 3, 'min_samples_leaf': 27, 'l2_regularization': 0.8195969482492831, 'random_state': 1305}. Best is trial 164 with value: 0.9386104925733989.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:44:43,289] Trial 743 finished with value: 0.9374438680682073 and parameters: {'learning_rate': 0.055339937270639766, 'max_iter': 410, 'max_leaf_nodes': 35, 'max_depth': 3, 'min_samples_leaf': 24, 'l2_regularization': 0.5405858894733324, 'random_state': 1947}. Best is trial 164 with value: 0.9386104925733989.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:44:44,223] Trial 744 finished with value: 0.9316180298099782 and parameters: {'learning_rate': 0.16588965344262493, 'max_iter': 419, 'max_leaf_nodes': 33, 'max_depth': 14, 'min_samples_leaf': 21, 'l2_regularization': 0.5930395447636579, 'random_state': 1515}. Best is trial 164 with value: 0.9386104925733989.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:44:44,883] Trial 745 finished with value: 0.93766445154714 and parameters: {'learning_rate': 0.11654628628437105, 'max_iter': 139, 'max_leaf_nodes': 31, 'max_depth': 3, 'min_samples_leaf': 28, 'l2_regularization': 0.7731449809078327, 'random_state': 357}. Best is trial 164 with value: 0.9386104925733989.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:44:45,724] Trial 746 finished with value: 0.9378161925527703 and parameters: {'learning_rate': 0.10715519432775489, 'max_iter': 276, 'max_leaf_nodes': 36, 'max_depth': 3, 'min_samples_leaf': 29, 'l2_regularization': 0.7947230421101381, 'random_state': 9722}. Best is trial 164 with value: 0.9386104925733989.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:44:46,696] Trial 747 finished with value: 0.9374096051033478 and parameters: {'learning_rate': 0.07898800968583221, 'max_iter': 239, 'max_leaf_nodes': 31, 'max_depth': 4, 'min_samples_leaf': 31, 'l2_regularization': 0.6247473000104586, 'random_state': 3855}. Best is trial 164 with value: 0.9386104925733989.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:44:47,448] Trial 748 finished with value: 0.9380031739815398 and parameters: {'learning_rate': 0.097611533310524, 'max_iter': 213, 'max_leaf_nodes': 38, 'max_depth': 3, 'min_samples_leaf': 27, 'l2_regularization': 0.7443980217777192, 'random_state': 707}. Best is trial 164 with value: 0.9386104925733989.
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [I 2024-12-31 17:44:48,409] Trial 749 finished with value: 0.9384121264638827 and parameters: {'learning_rate': 0.07017737062278372, 'max_iter': 289, 'max_leaf_nodes': 40, 'max_depth': 3, 'min_samples_leaf': 19, 'l2_regularization': 0.3544954355531158, 'random_state': 3}. Best is trial 164 with value: 0.9386104925733989.
# Best parameters: {'learning_rate': 0.05864689166323513, 'max_iter': 269, 'max_leaf_nodes': 31, 'max_depth': 3, 'min_samples_leaf': 27, 'l2_regularization': 0.8032649185759841, 'random_state': 1779}
# Best AUC score: 0.9386104925733989

# %%
study.best_trial
# Out:
# FrozenTrial(number=164, state=1, values=[0.9386104925733989], datetime_start=datetime.datetime(2024, 12, 31, 17, 35, 49, 523963), datetime_complete=datetime.datetime(2024, 12, 31, 17, 35, 50, 529300), params={'learning_rate': 0.05864689166323513, 'max_iter': 269, 'max_leaf_nodes': 31, 'max_depth': 3, 'min_samples_leaf': 27, 'l2_regularization': 0.8032649185759841, 'random_state': 1779}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'learning_rate': FloatDistribution(high=0.3, log=False, low=0.0001, step=None), 'max_iter': IntDistribution(high=500, log=False, low=50, step=1), 'max_leaf_nodes': IntDistribution(high=50, log=False, low=10, step=1), 'max_depth': IntDistribution(high=15, log=False, low=3, step=1), 'min_samples_leaf': IntDistribution(high=50, log=False, low=5, step=1), 'l2_regularization': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'random_state': IntDistribution(high=10000, log=False, low=0, step=1)}, trial_id=164, value=None)

# %%
# Train a final model using the best parameters
best_params = study.best_params
final_model = HistGradientBoostingClassifier(**best_params)
final_model.fit(X_train, y_train)

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
auc_scores = []

models=[]
for train_idx, val_idx in skf.split(X_train, y_train):
    X_train_fold, X_val_fold = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_train_fold, y_val_fold = y_train.iloc[train_idx], y_train.iloc[val_idx]
    
    model = HistGradientBoostingClassifier(**best_params)
    model.fit(X_train_fold, y_train_fold)
    a=model.fit(X_train_fold, y_train_fold)
    y_val_pred = model.predict_proba(X_val_fold)[:, 1]
    auc = roc_auc_score(y_val_fold, y_val_pred)
    models.append(a)
    auc_scores.append(auc)

auc_scores
# Out:
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\lamou\Documents\GitHub\challenge_data_mining\.venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0.9469737268801665,
#  0.9333403375363284,
#  0.9370807239127747,
#  0.94921337594539,
#  0.9227661251988876]

# %%
models
# Out:
# [HistGradientBoostingClassifier(l2_regularization=0.8032649185759841,
#                                 learning_rate=0.05864689166323513, max_depth=3,
#                                 max_iter=269, min_samples_leaf=27,
#                                 random_state=1779),
#  HistGradientBoostingClassifier(l2_regularization=0.8032649185759841,
#                                 learning_rate=0.05864689166323513, max_depth=3,
#                                 max_iter=269, min_samples_leaf=27,
#                                 random_state=1779),
#  HistGradientBoostingClassifier(l2_regularization=0.8032649185759841,
#                                 learning_rate=0.05864689166323513, max_depth=3,
#                                 max_iter=269, min_samples_leaf=27,
#                                 random_state=1779),
#  HistGradientBoostingClassifier(l2_regularization=0.8032649185759841,
#                                 learning_rate=0.05864689166323513, max_depth=3,
#                                 max_iter=269, min_samples_leaf=27,
#                                 random_state=1779),
#  HistGradientBoostingClassifier(l2_regularization=0.8032649185759841,
#                                 learning_rate=0.05864689166323513, max_depth=3,
#                                 max_iter=269, min_samples_leaf=27,
#                                 random_state=1779)]

# %%
models[0].predict_proba(X_val)[:,1]
# Out:
# array([0.0174481 , 0.00395904, 0.10411834, ..., 0.01290845, 0.00710993,
#        0.02653008])

# %%
# Evaluate the model on a validation set
y_val_pred = models[4].predict_proba(X_val)[:, 1]
final_auc = roc_auc_score(y_val, y_val_pred)
print(f"Validation ROC AUC: {final_auc:.4f}")
# Out:
# Validation ROC AUC: 0.9321

# %%
y_pred_proba_best = final_model.predict_proba(X_test)[:, 1]

sample_submission_test_N = data_test[['id']].copy()  # Copie uniquement la colonne 'id' de data_test
sample_submission_test_N["Exited"] = y_pred_proba_best  # Ajout des probabilités de churn

sample_submission_test_N.to_csv("results_hist.csv", index=False)
